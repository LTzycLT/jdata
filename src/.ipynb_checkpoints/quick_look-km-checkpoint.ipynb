# %%
import pandas
import numpy

# %%
comment = pandas.read_csv('../data/csv/JData_Comment.csv')
product = pandas.read_csv('../data/csv/JData_Product.csv')
user = pandas.read_csv('../data/csv/JData_User.csv')

# %%
user
# Out:
#         user_id     age  sex  user_lv_cd user_reg_dt
# 0            54      -1    2           1   2016/1/26
# 1            79  36-45岁    2           2   2016/1/27
# 2           100  16-25岁    2           3   2016/1/27
# 3           266   15岁以下    2           2   2016/1/29
# 4           333      -1    2           4   2016/1/30
# 5           605  26-35岁    2           2    2016/2/1
# 6           638  26-35岁    0           5   2010/8/12
# 7           686      -1    2           1    2016/2/1
# 8           692  16-25岁    2           2    2016/2/1
# 9           819  26-35岁    2           3    2016/2/2
# 10          861  36-45岁    2           3    2016/2/2
# 11         1204      -1    2           1    2016/2/7
# 12         1331      -1    2           1    2016/2/8
# 13         1334  26-35岁    2           2    2016/2/8
# 14         1394  36-45岁    2           2    2016/2/9
# 15         1422  26-35岁    2           3   2016/2/10
# 16         1442      -1    0           5   2010/8/16
# ...

# %%
product
# Out:
#        sku_id  attr1  attr2  attr3  cate  brand
# 0      166731      1     -1     -1     8    545
# 1      146488      2      2     -1     8    812
# 2       70546      3      1      1     8    214
# 3       92487      2      2     -1     8    812
# 4      113065      2      2     -1     8    812
# 5       80307      2      2     -1     8    812
# 6       71669      2      1     -1     8    812
# 7        4145      2      2      1     8    812
# 8       35450      2      2     -1     8    812
# 9      131403      2      1     -1     8    812
# 10     128621      2      1     -1     8    812
# 11      65347      2      1      2     8    812
# 12      68153      2      1      2     8    812
# 13      77945      2      1     -1     8    812
# 14     167028      2      1     -1     8    812
# 15      14771      2      1      2     8    812
# 16     153408      2      1     -1     8    812
# 17      39874      2      2     -1     8    812
# 18      83454      2      1     -1     8    812
# ...

# %%
action02 = pandas.read_csv('../data/csv/JData_Action_201602.csv')

# %%
action02[action02['user_id'] == 10396]
# Out:
#           user_id  sku_id                 time  model_id  type  cate  brand
# 2           10396   65823  2016-02-01 08:20:59       NaN     6     6     78
# 4           10396   65823  2016-02-01 08:20:56       NaN     6     6     78
# 5           10396   65823  2016-02-01 08:21:05       NaN     6     6     78
# 47          10396   65823  2016-02-01 08:21:05       NaN     6     6     78
# 7760        10396   65823  2016-02-01 08:21:13       NaN     6     6     78
# 137403      10396   65823  2016-02-01 08:20:57       NaN     1     6     78
# 1603250     10396   35988  2016-02-04 07:06:43       NaN     1     6     78
# 1603251     10396   35988  2016-02-04 07:06:43       NaN     1     6     78
# 1605178     10396  170626  2016-02-04 07:09:20       NaN     1     6     78
# 1605179     10396  170626  2016-02-04 07:09:20       NaN     1     6     78
# 1607372     10396   18585  2016-02-04 23:19:58       NaN     1     5    159
# ...
